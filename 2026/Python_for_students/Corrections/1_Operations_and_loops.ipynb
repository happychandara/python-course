# %% [markdown]
# # 1. Operations and loops

# %% [markdown]
# ## Correction

# %% [markdown]
# ### Exercise 1 - Print different values

# %% [markdown]
# 1. Display the sentence "I understand Python".

# %%
# Write your code here
print("I understand Python")
# Out:
# I understand Python

# %% [markdown]
# 2. Display the result of 168 - 99.

# %%
# Write your code here
print(168 - 99)
# Out:
# 69

# %% [markdown]
# 3. Display the boolean "True". Display the string "True". Then, check their type.

# %%
# Write your code here
print(True)
print("True")
print(type(True))
print(type("True"))
# Out:
# True
# True
# <class 'bool'>
# <class 'str'>

# %% [markdown]
# 4. Display the number 3.14, and the string "3.14". Then, check their type.

# %%
# Write your code here
print(3.14)
print("3.14")
print(type(3.14))
print(type("3.14"))
# Out:
# 3.14
# 3.14
# <class 'float'>
# <class 'str'>

# %% [markdown]
# 5. Which boolean do you think this expression is equal to : 7 == 4 + 5. Try to display the result of this equation to check your answer.

# %%
# Write your code here
print(7 == 4+5)
# Out:
# False

# %% [markdown]
# ### Exercise 2 - Declare a variable

# %% [markdown]
# 1. Declare the variable $x$, equal to 5. Then, display the value of $x$.

# %%
# Write your code here
x = 5 
print(x)
# Out:
# 5

# %% [markdown]
# 2. Declare the variable $a$, equal to 3, and the variable $b$, equal to 10. Then, display the result of $a+b$.

# %%
# Write your code here
a, b = 3, 10
print(a+b)
# Out:
# 13

# %% [markdown]
# 3. Declare the variable $c$, equal to `"Hello"` and the variable $d$, equal to `" world"`. Then, display $c+d$.

# %%
# Write your code here
c, d = "Hello", " world"
print(c+d)
# Out:
# Hello world

# %% [markdown]
# ### Exercise 3 - Student's level

# %% [markdown]
# Create an algorithm that prints "The student is in primary/secondary/high school" according to his/her grade. Then test your algorithm with `grade=2`, `grade=7` and `grade=11`.

# %%
grade = 2

if grade <= 6 : 
    print("The student is in primary school")
elif grade <= 9 : 
    print("The student is in secondary school")
else:
    print("The student is in high school")
# Out:
# The student is in primary school

# %% [markdown]
# ### Exercise 4 - Divide by 3

# %% [markdown]
# Create an algorithm that checks if a number can be divided by 3 or not, and print "yes" or "no" respectively. Test your algorithm with 6, 8, 15 and 0.

# %%
number = 6
if number % 3 == 0 : 
    print("yes")
else: 
    print("no")
# Out:
# yes

# %% [markdown]
# ### Exercise 5 - Sum of integers

# %% [markdown]
# Create an algorithm that displays the sum of the numbers between 1 and n (n included). Try your algorithm with 5, 10 and 100 000.

# %%
n = 10
sum = 0
for k in range(n+1):
    sum = sum + k 
print(sum)
# Out:
# 55

# %% [markdown]
# ### Exercise 6 - Fibonacci sequence

# %% [markdown]
# The Fibonacci sequence is a sequence of numbers, defined as follows :
# $F_{n+2}=F_{n+1} + F_n$, with $F_0 = 1$ and $F_1 = 1$.
# Create an algorithm that displays the `n` first numbers of this sequence and test it with `n=5` and `n=10`.

# %%
n = 5
a = 1
b = 1
print(a)
print(b)
for i in range(n):
    a, b = b, a+b
    print(b)
# Out:
# 1
# 1
# 2
# 3
# 5
# 8
# 13

# %% [markdown]
# ### Exercise 7 - Sales

# %% [markdown]
# Write a program that applies a reduction of 5% on a price, until the price is equal or below 100$, and then displays the new price. Try the program with 150$.

# %%
price = 150
while price > 100: 
    price = price * 0.95
print("The price after reduction is ", price, "$")
# Out:
# The price after reduction is  99.51306469335935 $

# %% [markdown]
# ### Exercise 8 - Guess the number

# %% [markdown]
# Write a program that makes the player guess a number between 1 and 10. Every time the player is wrong, display "Wrong number. Try again!". When the player is right, display "You guessed the number, well done!" and end the program.

# %% [markdown]
# Hint: you can use the function `random.randint(a,b)` that chooses a random number between `a` and `b`.
# You can also use the function `input(Sentence of the input)` to collect the input number from the player.

# %%
import random

guess_nb = random.randint(1, 11)
input_nb = int(input("Try a number : "))
while input_nb != guess_nb:
    print("Wrong number. Try again!")
    input_nb = int(input("Try a number : "))
print("You guessed the number, well done!")
# Out:
# guess_nb 4
# Wrong number. Try again!
# You guessed the number, well done!
