# %% [markdown]
# # 1. Revisions - operations and loops

# %% [markdown]
# ### Exercise 1 - Student's level

# %% [markdown]
# Create an algorithm that prints "The student is in primary/secondary/high school" according to his/her grade. Then test your algorithm with `grade=2`, `grade=7` and `grade=11`.

# %%
# Create your algorithm here

# %% [markdown]
# ### Exercise 2 - Divide by 3

# %% [markdown]
# Create an algorithm that checks if a number can be divided by 3 or not, and print "yes" or "no" respectively. Test your algorithm with 6, 8, 15 and 0.

# %%
# Create your algorithm here

# %% [markdown]
# ### Exercise 3 - Sum of integers

# %% [markdown]
# Create an algorithm that displays the sum of the numbers between 1 and n (n included). Try your algorithm with 5, 10 and 100 000.

# %%
# Create your algorithm here

# %% [markdown]
# ### Exercise 4 - Fibonacci sequence

# %% [markdown]
# The Fibonacci sequence is a sequence of numbers, defined as follows :
# $F_{n+2}=F_{n+1} + F_n$, with $F_0 = 1$ and $F_1 = 1$.
# Create an algorithm that displays the `n` first numbers of this sequence and test it with `n=5` and `n=10`.

# %%
# Create your algorithm here

# %% [markdown]
# ### Exercise 5 - Sales

# %% [markdown]
# Write a program that applies a reduction of 5% on a price, until the price is equal or below 100$, and then displays the new price. Try the program with 150$.

# %%
# Create your algorithm here

# %% [markdown]
# ### Exercise 6 - Guess the number

# %% [markdown]
# Write a program that makes the player guess a number between 1 and 10. Every time the player is wrong, display "Wrong number. Try again!". When the player is right, display "You guessed the number, well done!" and end the program.

# %% [markdown]
# Hint: you can use the function `random.randint(a,b)` that chooses a random number between `a` and `b`.
# You can also use the function `input(Sentence of the input)` to collect the input number from the player.

# %%
#import the library random 
import random

# Create your algorithm here

# %% [markdown]
# ### Exercise 7 - Create a function

# %% [markdown]
# Complete the functions `perimeter` and `area` to use them to calculate the perimeter and the area of a rectangle.

# %%
def perimeter(a, b):
    # Modify the function
    return 
    
def area(a, b):
    # Modify the function
    return

# Don't touch this part
length, width = 4, 5
print("For a rectangle of length", length, "and width", width, "the perimeter is", perimeter(length, width), "and the area is", area(length, width))
# Out:
# For a rectangle of length 4 and width 5 the perimeter is None and the area is None

# %% [markdown]
# ### Exercise 8 - Use a function to improve readability

# %% [markdown]
# Here is an algorithm very repetitive, that could be optimized by creating a function. Try to re-write the algorithm using a function. Ensure your function works.

# %%
number = 32
n, m = number, number
while n % 3 == 0 : 
    n = n // 3 
if n == 1 : 
    print(number, "is a power of 3")
else : 
    print(number, "is not a power of 3")
while m % 2 == 0 : 
    m = m // 2
if m == 1 : 
    print(number, "is a power of 2")
else : 
    print(number, "is not a power of 2")
# Out:
# 32 is not a power of 3
# 32 is a power of 2

# %%
def isPowerOf(input, multiple):
    # Complete the function here
    return 

isPowerOf(32, 3)
isPowerOf(32, 2)
